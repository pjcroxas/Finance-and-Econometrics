# %% [markdown]
# <a href="https://www.kaggle.com/code/patrickjose/analysis-of-2017-world-economic-data?scriptVersionId=229031252" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import plotly.express as px

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/undata-country-profiles/country_profile_variables.csv
# /kaggle/input/undata-country-profiles/kiva_country_profile_variables.csv

# %%
dirs_1 = "/kaggle/input/undata-country-profiles/country_profile_variables.csv"
dirs_2 = "/kaggle/input/undata-country-profiles/kiva_country_profile_variables.csv"

# %%
# render and combine data
undp = pd.read_csv(dirs_1)
undp2 = pd.read_csv(dirs_2)
un_stat = pd.concat([undp, undp2], ignore_index=True)
un_stat.drop_duplicates(subset=["country"], inplace=True)
un_stat.head()
# Out:
#           country          Region Surface area (km2)  \
# 0     Afghanistan    SouthernAsia             652864
# 1         Albania  SouthernEurope              28748
# 2         Algeria  NorthernAfrica            2381741
# 3  American Samoa       Polynesia                199
# 4         Andorra  SouthernEurope                468
#
#    Population in thousands (2017)  Population density (per km2, 2017)  \
# 0                           35530                                54.4
# 1                            2930                               106.9
# 2                           41318                                17.3
# 3                              56                               278.2
# 4                              77                               163.8
#
#    Sex ratio (m per 100 f, 2017)  \
# 0                          106.3
# 1                          101.9
# 2                          102.0
# 3                          103.6
# 4                          102.3
#
# ...

# %%
# Check duplicates
un_stat[un_stat["country"]=="Philippines"]
# Out:
#          country             Region Surface area (km2)  \
# 159  Philippines  South-easternAsia             300000
#
#      Population in thousands (2017)  Population density (per km2, 2017)  \
# 159                          104918                               351.9
#
#      Sex ratio (m per 100 f, 2017)  \
# 159                          101.3
#
#      GDP: Gross domestic product (million current US$)  \
# 159                                             292449
#
#     GDP growth rate (annual %, const. 2005 prices)  \
# 159                                            5.9
#
#      GDP per capita (current US$) Economy: Agriculture (% of GVA)  ...  \
# 159                        2904.2                            10.5  ...
#
#      Mobile-cellular subscriptions (per 100 inhabitants).1  \
# 159                                               40.7
#
#      Individuals using the Internet (per 100 inhabitants)  \
# 159                                                783
#
# ...

# %%
un_stat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 239 entries, 0 to 311
# Data columns (total 50 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   country                                                     239 non-null    object
#  1   Region                                                      239 non-null    object
#  2   Surface area (km2)                                          239 non-null    object
#  3   Population in thousands (2017)                              239 non-null    int64
#  4   Population density (per km2, 2017)                          239 non-null    float64
#  5   Sex ratio (m per 100 f, 2017)                               239 non-null    float64
#  6   GDP: Gross domestic product (million current US$)           239 non-null    int64
# ...

# %%
un_stat[un_stat["GDP growth rate (annual %, const. 2005 prices)"]== "-~0.0"]
# Out:
#          country     Region Surface area (km2)  \
# 162  Puerto Rico  Caribbean               8868
#
#      Population in thousands (2017)  Population density (per km2, 2017)  \
# 162                            3663                               413.0
#
#      Sex ratio (m per 100 f, 2017)  \
# 162                           92.6
#
#      GDP: Gross domestic product (million current US$)  \
# 162                                             102906
#
#     GDP growth rate (annual %, const. 2005 prices)  \
# 162                                          -~0.0
#
#      GDP per capita (current US$) Economy: Agriculture (% of GVA)  ...  \
# 162                       27939.0                             0.8  ...
#
#      Mobile-cellular subscriptions (per 100 inhabitants).1  \
# 162                                               79.5
#
#      Individuals using the Internet (per 100 inhabitants)  \
# 162                                                126
#
# ...

# %%
# def clean_numeric_columns(df, columns):
#     def clean_value(value):
#         if isinstance(value, str):
#             value = value.replace('~', '').strip()
#             if value == '...':
#                 return 0.0
#         try:
#             return float(value)
#         except ValueError:
#             return None  # or np.nan if using NumPy

#     for col in columns:
#         df[col] = df[col].apply(clean_value)
    
#     return df

# %%
# numerics_cols = un_stat.select_dtypes(include=float)
# string_cols = un_stat.select_dtypes(exclude=float)
# to_numeric_cols = clean_numeric_columns(string_cols, string_cols.columns)

# %%
un_stat.describe()
# Out:
#        Population in thousands (2017)  Population density (per km2, 2017)  \
# count                    2.390000e+02                          239.000000
# mean                     3.413285e+04                          451.212552
# std                      1.319691e+05                         2257.625510
# min                      1.000000e+00                            0.100000
# 25%                      4.430000e+02                           35.900000
# 50%                      5.709000e+03                           87.300000
# 75%                      2.276550e+04                          224.050000
# max                      1.409517e+06                        25969.800000
#
#        Sex ratio (m per 100 f, 2017)  \
# count                     239.000000
# mean                      100.101674
# std                        27.741170
# min                       -99.000000
# 25%                        96.400000
# 50%                        99.000000
# ...

# %%
# eliminate special characters in gdp growth rate
un_stat['GDP growth rate (annual %, const. 2005 prices)'] = un_stat['GDP growth rate (annual %, const. 2005 prices)'].replace('~', '', regex=True)

# %%
# replace "~" to empty string
un_stat["GDP growth rate (annual %, const. 2005 prices)"] = un_stat["GDP growth rate (annual %, const. 2005 prices)"].replace('~', '', regex=True)

# Convert objects to float
un_stat["GDP growth rate (annual %, const. 2005 prices)"] = un_stat["GDP growth rate (annual %, const. 2005 prices)"].astype(float)

# %%
gdp_per_region = un_stat.groupby("Region").agg({
    "GDP: Gross domestic product (million current US$)":"mean",
    "GDP growth rate (annual %, const. 2005 prices)":"mean",
    "GDP per capita (current US$)":"mean",
    "Population in thousands (2017)":"sum"    
}).reset_index()

gdp_per_region.sort_values(by="Population in thousands (2017)",ascending=False, inplace=True)
gdp_per_region.head()
# Out:
#                Region  GDP: Gross domestic product (million current US$)  \
# 17       SouthernAsia                                       3.449421e+05
# 4         EasternAsia                                       2.471837e+06
# 14  South-easternAsia                                       2.074378e+05
# 10    NorthernAmerica                                       6.272323e+06
# 3       EasternAfrica                                       1.759490e+04
#
#     GDP growth rate (annual %, const. 2005 prices)  \
# 17                                        3.688889
# 4                                        -0.857143
# 14                                        5.138462
# 10                                      -15.366667
# 3                                        -0.690000
#
#     GDP per capita (current US$)  Population in thousands (2017)
# 17                   2968.400000                         1868985
# 4                   27967.614286                         1624538
# ...

# %% [markdown]
# 1. `GDP: Gross Domestic Product (million current US$)` – The total monetary value of all final goods and services produced within a country’s borders in a given year, measured in current U.S. dollars (i.e., not adjusted for inflation).
#
# 2. `GDP Growth Rate (annual %, constant 2005 prices)` – The percentage change in a country’s GDP from one year to the next, adjusted for inflation using 2005 as the base year. This measure reflects real economic growth by accounting for price changes over time.
#
# 3. `GDP per Capita (current US$)` – The GDP divided by the total population of a country, expressed in current U.S. dollars. It provides an estimate of the average economic output or income per person in a given year, without adjusting for inflation.

# %%
fig = px.sunburst(un_stat, path=['Region', 'country'], values='Population in thousands (2017)',
                  color='Region', hover_data=['Population in thousands (2017)'])
fig.show(renderer='iframe_connected')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_13.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
fig = px.bar(gdp_per_region,
            x="Region",
            y="Population in thousands (2017)").update_layout(template="plotly_white", 
                                                              title="Population per Region (2017)")

fig.show(renderer='iframe_connected')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_14.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
gdp_pop_corr = gdp_per_region["GDP: Gross domestic product (million current US$)"].corr(gdp_per_region["Population in thousands (2017)"])
fig = px.scatter(gdp_per_region,
            x="GDP: Gross domestic product (million current US$)",
            y="Population in thousands (2017)",
            size="Population in thousands (2017)",
            color="Region",
            text="Region").update_layout(template="plotly_white",
                                         title= f"GDP vs Population (corr={np.round(gdp_pop_corr,3)})")
fig.show(renderer='iframe_connected')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_15.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
gdp_capita_pop_corr = gdp_per_region["GDP: Gross domestic product (million current US$)"].corr(gdp_per_region["GDP per capita (current US$)"])
fig = px.scatter(gdp_per_region,
            x="GDP per capita (current US$)",
            y="Population in thousands (2017)",
            size="Population in thousands (2017)",
            color="Region",
            text="Region").update_layout(template="plotly_white",
                                         title= f"GDP vs Population (corr={np.round(gdp_capita_pop_corr, 3)})")
fig.show(renderer='iframe_connected')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_16.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# # Economic Structure and Sectoral Contribution

# %%
# String checker (do not delete)
# un_stat["Employment: Agriculture (% of employed)"] = un_stat["Employment: Agriculture (% of employed)"].astype(float)
# un_stat[un_stat["Employment: Agriculture (% of employed)"] == "..."][["country","Employment: Agriculture (% of employed)"]]

# replace "..." to empty string
un_stat["Economy: Agriculture (% of GVA)"] = un_stat["Economy: Agriculture (% of GVA)"].replace('...', '0', regex=True)
un_stat["Economy: Industry (% of GVA)"] = un_stat["Employment: Industry (% of employed)"].replace('...', '0', regex=True)
un_stat["Economy: Services and other activity (% of GVA)"] = un_stat["Economy: Services and other activity (% of GVA)"].replace('...', '0', regex=True)
un_stat["Employment: Agriculture (% of employed)"] = un_stat["Employment: Agriculture (% of employed)"].replace('...', '0', regex=True)
un_stat["Employment: Industry (% of employed)"] = un_stat["Employment: Industry (% of employed)"].replace('...', '0', regex=True)
un_stat["Employment: Services (% of employed)"] = un_stat["Employment: Services (% of employed)"].replace('...', '0', regex=True)

# Convert objects to float
un_stat["Economy: Agriculture (% of GVA)"] = un_stat["Economy: Agriculture (% of GVA)"].astype(float)
un_stat["Economy: Industry (% of GVA)"] = un_stat["Economy: Industry (% of GVA)"] .astype(float)
un_stat["Economy: Services and other activity (% of GVA)"] = un_stat["Economy: Services and other activity (% of GVA)"].astype(float)
un_stat["Employment: Agriculture (% of employed)"] = un_stat["Employment: Agriculture (% of employed)"].astype(float)
un_stat["Employment: Industry (% of employed)"] = un_stat["Employment: Industry (% of employed)"].astype(float)
un_stat["Employment: Services (% of employed)"] = un_stat["Employment: Services (% of employed)"].astype(float)

# %%
sectoral_perf_region = un_stat.groupby("Region").agg({
    "Employment: Agriculture (% of employed)":"mean",
    "Employment: Industry (% of employed)":"mean",
    "Employment: Services (% of employed)":"mean",
    "Economy: Agriculture (% of GVA)": "mean",
    "Economy: Industry (% of GVA)": "mean",
    "Economy: Services and other activity (% of GVA)":"mean"   , 
    "Population in thousands (2017)":"mean",
    "GDP: Gross domestic product (million current US$)":"mean"
    
}).reset_index()

sectoral_perf_region.sort_values(by="Population in thousands (2017)",ascending=False, inplace=True)
sectoral_perf_region.head()
# Out:
#                Region  Employment: Agriculture (% of employed)  \
# 4         EasternAsia                                 1.857143
# 17       SouthernAsia                                 4.222222
# 10    NorthernAmerica                                 0.250000
# 14  South-easternAsia                                 8.723077
# 9      NorthernAfrica                                 5.571429
#
#     Employment: Industry (% of employed)  \
# 4                               6.714286
# 17                              5.000000
# 10                              5.533333
# 14                              6.115385
# 9                               4.714286
#
#     Employment: Services (% of employed)  Economy: Agriculture (% of GVA)  \
# 4                               4.285714                         2.000000
# 17                              4.777778                         2.555556
# 10                             16.550000                         0.166667
# ...

# %%
gdp_agri_econ = sectoral_perf_region["Economy: Agriculture (% of GVA)"].corr(sectoral_perf_region["GDP: Gross domestic product (million current US$)"])
fig = px.scatter(sectoral_perf_region,
            x="Employment: Agriculture (% of employed)",
            y="Economy: Agriculture (% of GVA)",
            size="Population in thousands (2017)",
            color="Region",
            text="Region").update_layout(template="plotly_white",
                                         title= f"Agricultural Sector: Economy vs Employment <br><sup>corr (GDP-GVA): {np.round(gdp_agri_econ, 3)}<sup>")
fig.show(renderer='iframe_connected')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_19.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
gdp_agri_econ = sectoral_perf_region["Economy: Services and other activity (% of GVA)"].corr(sectoral_perf_region["GDP: Gross domestic product (million current US$)"])
fig = px.scatter(sectoral_perf_region,
            x="Employment: Services (% of employed)",
            y="Economy: Services and other activity (% of GVA)",
            size="Population in thousands (2017)",
            color="Region",
            text="Region").update_layout(template="plotly_white",
                                         title= f"Other Services Sector: Economy vs Employment <br><sup>corr (GDP-GVA): {np.round(gdp_agri_econ, 3)}<sup>")
fig.show(renderer='iframe_connected')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_20.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
gdp_agri_econ = sectoral_perf_region["Economy: Industry (% of GVA)"].corr(sectoral_perf_region["GDP: Gross domestic product (million current US$)"])
fig = px.scatter(sectoral_perf_region,
            x="Employment: Industry (% of employed)",
            y="Economy: Industry (% of GVA)",
            size="Population in thousands (2017)",
            color="Region",
            text="Region").update_layout(template="plotly_white",
                                         title= f"Industrial Sector: Economy vs Employment <br><sup>corr (GDP-GVA): {np.round(gdp_agri_econ, 3)}<sup>")
fig.show(renderer='iframe_connected')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_21.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# # Trade and Economic Balance

# %%
def replace_convert(char, data, feature):
    # replace char to empty string
    data[feature] = data[feature].replace(char, '0', regex=True)
    return data

# %%
un_stat_trade = un_stat.copy()
trade_cols = ['International trade: Exports (million US$)',
              'International trade: Imports (million US$)',
              'International trade: Balance (million US$)']


for cols in trade_cols:
    replace_convert('...', un_stat_trade, cols)
    
for cols in trade_cols:
    replace_convert('~', un_stat_trade, cols)

for cols in trade_cols:
    un_stat_trade[cols] = un_stat_trade[cols].astype(float)

# %%
px.box(un_stat_trade,
          x="Region",
          y="International trade: Imports (million US$)",
          # text="country",
          color="Region",
          log_y=True).update_layout(template="plotly_white",
                                   title="Imports per Region")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.box(un_stat_trade,
          x="Region",
          y="International trade: Exports (million US$)",
          # text="country",
          color="Region",
          log_y=True).update_layout(template="plotly_white",
                                   title="Exports per Region")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
gdp_trade = un_stat_trade.groupby('Region').agg({
    'GDP: Gross domestic product (million current US$)':'mean',
    'GDP per capita (current US$)':'mean',
    'International trade: Exports (million US$)':'mean',
    'International trade: Imports (million US$)':'mean',
    'International trade: Balance (million US$)':'mean',
    
}).reset_index()
gdp_trade.head()
# Out:
#            Region  GDP: Gross domestic product (million current US$)  \
# 0       Caribbean                                       1.285412e+04
# 1  CentralAmerica                                       1.712796e+05
# 2     CentralAsia                                       6.055600e+04
# 3   EasternAfrica                                       1.759490e+04
# 4     EasternAsia                                       2.471837e+06
#
#    GDP per capita (current US$)  International trade: Exports (million US$)  \
# 0                  14263.903846                                    9.653846
# 1                   6348.137500                                   12.125000
# 2                   4329.880000                                   25.200000
# 3                   1867.790000                                  241.250000
# 4                  27967.614286                                    2.142857
#
#    International trade: Imports (million US$)  \
# ...

# %%
fig = px.scatter(gdp_trade,
            x="International trade: Exports (million US$)",
            y="GDP: Gross domestic product (million current US$)",
            color="Region",
            log_x=True,
            size="GDP: Gross domestic product (million current US$)",
            text="Region").update_layout(template="plotly_white")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
gdp_per_capita_trade_balance = gdp_trade["International trade: Balance (million US$)"].corr(gdp_trade["GDP per capita (current US$)"])
fig = px.scatter(gdp_trade,
            x="International trade: Imports (million US$)",
            y="GDP: Gross domestic product (million current US$)",
            color="Region",
            log_x=True,
            size="GDP: Gross domestic product (million current US$)",
            text="Region").update_layout(template="plotly_white",
                                        title=f"International Trade vs GDP <br><sup>corr (GDP per Capita vs Trade Balance) : {gdp_per_capita_trade_balance}</sup>")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
